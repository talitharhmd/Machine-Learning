# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X=iris.iloc[:,1:5].values
y=iris.iloc[:,5].values

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

#Train and Test split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)
# Out:
# (120, 4) (30, 4)

# %%
X_train
# Out:
#      PetalLengthCm  PetalWidthCm          Species  SepalWidthCm
# 0              1.4           0.2      Iris-setosa           3.5
# 143            5.9           2.3   Iris-virginica           3.2
# 72             4.9           1.5  Iris-versicolor           2.5
# 116            5.5           1.8   Iris-virginica           3.0
# 20             1.7           0.2      Iris-setosa           3.4
# ..             ...           ...              ...           ...
# 85             4.5           1.6  Iris-versicolor           3.4
# 128            5.6           2.1   Iris-virginica           2.8
# 119            5.0           1.5   Iris-virginica           2.2
# 133            5.1           1.5   Iris-virginica           2.8
# 140            5.6           2.4   Iris-virginica           3.1
#
# [120 rows x 4 columns]

# %%
X_test
# Out:
#      PetalLengthCm  PetalWidthCm          Species  SepalWidthCm
# 6              1.4           0.3      Iris-setosa           3.4
# 61             4.2           1.5  Iris-versicolor           3.0
# 90             4.4           1.2  Iris-versicolor           2.6
# 30             1.6           0.2      Iris-setosa           3.1
# 31             1.5           0.4      Iris-setosa           3.4
# 55             4.5           1.3  Iris-versicolor           2.8
# 109            6.1           2.5   Iris-virginica           3.6
# 98             3.0           1.1  Iris-versicolor           2.5
# 59             3.9           1.4  Iris-versicolor           2.7
# 103            5.6           1.8   Iris-virginica           2.9
# 126            4.8           1.8   Iris-virginica           2.8
# 97             4.3           1.3  Iris-versicolor           2.9
# 74             4.3           1.3  Iris-versicolor           2.9
# 67             4.1           1.0  Iris-versicolor           2.7
# 115            5.3           2.3   Iris-virginica           3.2
# 25             1.6           0.2      Iris-setosa           3.0
# 95             4.2           1.2  Iris-versicolor           3.0
# 100            6.0           2.5   Iris-virginica           3.3
# 9              1.5           0.1      Iris-setosa           3.1
# 129            5.8           1.6   Iris-virginica           3.0
# 71             4.0           1.3  Iris-versicolor           2.8
# 47             1.4           0.2      Iris-setosa           3.2
# 86             4.7           1.5  Iris-versicolor           3.1
# 57             3.3           1.0  Iris-versicolor           2.4
# 48             1.5           0.2      Iris-setosa           3.7
# 5              1.7           0.4      Iris-setosa           3.9
# 112            5.5           2.1   Iris-virginica           3.0
# 148            5.4           2.3   Iris-virginica           3.4
# 122            6.7           2.0   Iris-virginica           2.8
# 78             4.5           1.5  Iris-versicolor           2.9

# %%
X_train.to_csv('train.csv', index=False)
X_test.to_csv('test.csv', index=False)
